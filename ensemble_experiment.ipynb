# %% [markdown]
# #### this file aims to ensemble predictions in step3 in our report.

# %%
import pandas as pds
# file paths that you want to ensemble
files = ['./submit7_res.csv', './submit5_inc.csv']

# %%
def ensemble(list_filename):
  numeric_col = ['ALB', 'BET', 'DOL', 'LAG', 'NoF', 'OTHER', 'SHARK', 'YFT']
  n = len(list_filename)
  values = pds.read_csv(list_filename[0])[numeric_col]
  for i in range(1, n):
    values += pds.read_csv(list_filename[i])[numeric_col]
  values /= n
  final = pds.read_csv(list_filename[0])
  final[numeric_col] = values
  return final

# %%
ensemble(files)
# Out:
#                            image       ALB       BET       DOL       LAG  \
# 0                  img_00005.jpg  0.227574  0.026469  0.015487  0.008867
# 1                  img_00007.jpg  0.232413  0.069330  0.015528  0.008929
# 2                  img_00009.jpg  0.717808  0.029052  0.015485  0.008868
# 3                  img_00018.jpg  0.686168  0.066080  0.015496  0.009010
# 4                  img_00027.jpg  0.664528  0.027456  0.015487  0.008867
# ...                          ...       ...       ...       ...       ...
# 13148  test_stg2/image_12149.jpg  0.575196  0.053697  0.015627  0.008873
# 13149  test_stg2/image_12150.jpg  0.727085  0.026475  0.015485  0.008867
# 13150  test_stg2/image_12151.jpg  0.717156  0.026486  0.016118  0.008874
# 13151  test_stg2/image_12152.jpg  0.313160  0.026508  0.015485  0.008868
# 13152  test_stg2/image_12153.jpg  0.630941  0.061074  0.040091  0.008871
#
#             NoF     OTHER     SHARK       YFT
# 0      0.561464  0.039571  0.023293  0.097144
# 1      0.061540  0.039586  0.023295  0.549246
# 2      0.061540  0.046679  0.023294  0.097143
# 3      0.061540  0.041017  0.023294  0.097263
# 4      0.061544  0.039576  0.023325  0.159083
# ...         ...       ...       ...       ...
# 13148  0.061914  0.040760  0.023386  0.220415
# 13149  0.061757  0.039583  0.023294  0.097322
# 13150  0.068929  0.039963  0.023395  0.098946
# 13151  0.475396  0.039879  0.023387  0.097186
# 13152  0.061937  0.053850  0.024859  0.118245
#
# [13153 rows x 9 columns]

# %%
# save files
ensemble(files).to_csv('./ensem.csv', index=None)
